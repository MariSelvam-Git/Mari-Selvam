# %%
import pandas as pd

# %%
df=pd.read_csv("gender_classification_v7.csv")

# %%
df
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0             1               11.8                 6.1          1          0
# 1             0               14.0                 5.4          0          0
# 2             0               11.8                 6.3          1          1
# 3             0               14.4                 6.1          0          1
# 4             1               13.5                 5.9          0          0
# ...         ...                ...                 ...        ...        ...
# 4996          1               13.6                 5.1          0          0
# 4997          1               11.9                 5.4          0          0
# 4998          1               12.9                 5.7          0          0
# 4999          1               13.2                 6.2          0          0
# 5000          1               15.4                 5.4          1          1
#
# ...

# %%
print(df.to_string())
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  lips_thin  distance_nose_to_lip_long  gender
# 0             1               11.8                 6.1          1          0          1                          1    Male
# 1             0               14.0                 5.4          0          0          1                          0  Female
# 2             0               11.8                 6.3          1          1          1                          1    Male
# 3             0               14.4                 6.1          0          1          1                          1    Male
# 4             1               13.5                 5.9          0          0          0                          0  Female
# 5             1               13.0                 6.8          1          1          1                          1    Male
# 6             1               15.3                 6.2          1          1          1                          0    Male
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5001 entries, 0 to 5000
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   long_hair                  5001 non-null   int64
#  1   forehead_width_cm          5001 non-null   float64
#  2   forehead_height_cm         5001 non-null   float64
#  3   nose_wide                  5001 non-null   int64
#  4   nose_long                  5001 non-null   int64
#  5   lips_thin                  5001 non-null   int64
#  6   distance_nose_to_lip_long  5001 non-null   int64
#  7   gender                     5001 non-null   object
# dtypes: float64(2), int64(5), object(1)
# memory usage: 312.7+ KB

# %%
df.describe()
# Out:
#          long_hair  forehead_width_cm  forehead_height_cm    nose_wide  \
# count  5001.000000        5001.000000         5001.000000  5001.000000
# mean      0.869626          13.181484            5.946311     0.493901
# std       0.336748           1.107128            0.541268     0.500013
# min       0.000000          11.400000            5.100000     0.000000
# 25%       1.000000          12.200000            5.500000     0.000000
# 50%       1.000000          13.100000            5.900000     0.000000
# 75%       1.000000          14.000000            6.400000     1.000000
# max       1.000000          15.500000            7.100000     1.000000
#
#          nose_long    lips_thin  distance_nose_to_lip_long
# count  5001.000000  5001.000000                5001.000000
# mean      0.507898     0.493101                   0.498900
# std       0.499988     0.500002                   0.500049
# min       0.000000     0.000000                   0.000000
# ...

# %%
df.shape
# Out:
# (5001, 8)

# %%
df.columns
# Out:
# Index(['long_hair', 'forehead_width_cm', 'forehead_height_cm', 'nose_wide',
#        'nose_long', 'lips_thin', 'distance_nose_to_lip_long', 'gender'],
#       dtype='object')

# %%
df.head()
# Out:
#    long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0          1               11.8                 6.1          1          0
# 1          0               14.0                 5.4          0          0
# 2          0               11.8                 6.3          1          1
# 3          0               14.4                 6.1          0          1
# 4          1               13.5                 5.9          0          0
#
#    lips_thin  distance_nose_to_lip_long  gender
# 0          1                          1    Male
# 1          1                          0  Female
# 2          1                          1    Male
# 3          1                          1    Male
# 4          0                          0  Female

# %%
df.tail()
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 4996          1               13.6                 5.1          0          0
# 4997          1               11.9                 5.4          0          0
# 4998          1               12.9                 5.7          0          0
# 4999          1               13.2                 6.2          0          0
# 5000          1               15.4                 5.4          1          1
#
#       lips_thin  distance_nose_to_lip_long  gender
# 4996          0                          0  Female
# 4997          0                          0  Female
# 4998          0                          0  Female
# 4999          0                          0  Female
# 5000          1                          1    Male

# %%
df.columns
# Out:
# Index(['long_hair', 'forehead_width_cm', 'forehead_height_cm', 'nose_wide',
#        'nose_long', 'lips_thin', 'distance_nose_to_lip_long', 'gender'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# long_hair                    0
# forehead_width_cm            0
# forehead_height_cm           0
# nose_wide                    0
# nose_long                    0
# lips_thin                    0
# distance_nose_to_lip_long    0
# gender                       0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
numeric_cols=df.select_dtypes(include="number").columns

# %%
sns.histplot(df["long_hair"],bins=10,kde=True)
# Out:
# <Axes: xlabel='long_hair', ylabel='Count'>

# %%
sns.histplot(df["forehead_width_cm"],bins=10,kde=True)
# Out:
# <Axes: xlabel='forehead_width_cm', ylabel='Count'>

# %%
sns.histplot(df["forehead_height_cm"],bins=10,kde=True)
# Out:
# <Axes: xlabel='forehead_height_cm', ylabel='Count'>

# %%
sns.histplot(df["nose_wide"],bins=10,kde=True)
# Out:
# <Axes: xlabel='nose_wide', ylabel='Count'>

# %%
sns.histplot(df["nose_long"],bins=10,kde=True)
# Out:
# <Axes: xlabel='nose_long', ylabel='Count'>

# %%
sns.histplot(df["lips_thin"],bins=10,kde=True)
# Out:
# <Axes: xlabel='lips_thin', ylabel='Count'>

# %%
sns.histplot(df["distance_nose_to_lip_long"],bins=10,kde=True)
# Out:
# <Axes: xlabel='distance_nose_to_lip_long', ylabel='Count'>

# %%
sns.histplot(df["gender"],bins=10,kde=True)
# Out:
# <Axes: xlabel='gender', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['long_hair', 'forehead_width_cm', 'forehead_height_cm', 'nose_wide',
#        'nose_long', 'lips_thin', 'distance_nose_to_lip_long', 'gender'],
#       dtype='object')

# %%
columns=['long_hair', 'forehead_width_cm', 'forehead_height_cm', 'nose_wide',
       'nose_long', 'lips_thin', 'distance_nose_to_lip_long']
for col in columns:
    Q1=df[col].quantile(0.25)
    Q3=df[col].quantile(0.75)
    IQR=Q3-Q1

    LOWER_BOUND=Q1-1.5*IQR
    UPPER_BOUND=Q3+1.5*IQR
    outliers=df[(df[col]<LOWER_BOUND) | (df[col]>UPPER_BOUND)]
    print(outliers.shape[0])
# Out:
# 652
# 0
# 0
# 0
# 0
# 0
# 0

# %%
columns=['long_hair', 'forehead_width_cm', 'forehead_height_cm', 'nose_wide',
       'nose_long', 'lips_thin', 'distance_nose_to_lip_long']
for col in columns:
    Q1=df[col].quantile(0.25)
    Q3=df[col].quantile(0.75)
    IQR=Q3-Q1

    LOWER_BOUND=Q1-1.5*IQR
    UPPER_BOUND=Q3+1.5*IQR
    outliers=df[(df[col]<LOWER_BOUND) | (df[col]>UPPER_BOUND)]
    df[col]=df[col].clip(lower=LOWER_BOUND,upper=UPPER_BOUND)
    print(outliers.shape[0])
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0

# %%
colors=['black','orange','red','purple','yellow','green','blue']
plt.figure(figsize=(12,14))
avg_scores_by_gender = df.groupby("gender")[['long_hair', 'forehead_width_cm', 'forehead_height_cm', 'nose_wide',
       'nose_long', 'lips_thin', 'distance_nose_to_lip_long']].mean().reset_index()
avg_scores_by_gender.set_index("gender").plot(kind='bar',color=colors,width=0.9)
plt.title("Size of Genders")
plt.ylabel("Average Score")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(19,5))
sns.boxplot(data=df)
plt.title("Size of Genders")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df,x='forehead_width_cm',y='forehead_height_cm',hue='gender')
plt.title("Male VS Female")
plt.show()

# %%
plt.figure(figsize=(8,5))
df_sorted = df.sort_values(by='distance_nose_to_lip_long')
plt.plot(df_sorted['distance_nose_to_lip_long'].values, marker='x',linestyle='--')
plt.title("Gender Visualization")
plt.xlabel("")
plt.ylabel("")
plt.show()

# %%
df.to_csv('Gender_Visualization.csv',index=False)
